# %%
import os
import numpy as np
import nibabel as nib
import pickle as pkl
import torch
import SimpleITK as sitk

# %%
root = "/home/user/disk/shaobo/FDG-Pet/TLE220"

# %%
path_list = os.listdir(root)
for sub in path_list:
    mask_path_ = os.path.join(root,sub,'MASK')
    nii_list = os.listdir(mask_path_)
    mask_path = os.path.join(mask_path_,nii_list[0])
    # print(len(nii_list))
    mask_img = nib.load(mask_path).get_fdata()
    # left = mask_img[256:,:,:]
    # right = mask_img[:256,:,:]
    # flipped_right = np.flip(left,0)
    # newmask = np.concatenate([flipped_right,left],0)
    # # nii_file = sitk.GetImageFromArray(flipped_right)
    # # raw = sitk.GetImageFromArray(mask_img)
    # aff =nib.load(mask_path).affine
    # nib.Nifti1Image(newmask,aff).to_filename('newmask.nii')
    # print(mask_path)
    flipped = np.flip(mask_img,0)
    print(flipped.dtype)
    newmask = np.logical_or(flipped,mask_img).astype(float)
    aff =nib.load(mask_path).affine
    nib.Nifti1Image(newmask,aff).to_filename(os.path.join(mask_path_,'newmask.nii'))#os.path.join(mask_path_,
    # break
# Out:
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# ...

# %%
a = [1,0,0]
b = [0,0,1]
import numpy as np
np.logical_or(a,b).astype(float)
# Out:
# array([1., 0., 1.])
